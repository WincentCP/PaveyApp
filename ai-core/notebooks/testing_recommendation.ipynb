# %% [markdown]
# # Inisialisasi Recommender Tuned

# %%
import os
import sys

# Mengambil path dari root proyek (1 tingkat di atas folder notebooks)
notebook_dir = os.getcwd()
root_dir = os.path.abspath(os.path.join(notebook_dir, ".."))

# Daftarkan root direktori ke dalam sys.path milik Python jika belum ada
if root_dir not in sys.path:
    sys.path.append(root_dir)

print(f"[INFO] Berhasil menambahkan root ke sys.path: {root_dir}")
# Out:
# [INFO] Berhasil menambahkan root ke sys.path: /home/kiana/Downloads/Hasil_Scraping_Pariwisata/travel-rec

# %%
import pandas as pd
from datetime import datetime
from sentence_transformers import SentenceTransformer
from src.components.preprocessing import DataPreprocessor
from src.components.feature_engineering import FeatureEngineer
from src.components.recommender import SemanticRecommender

# Load and process pipeline
df = pd.read_csv("/home/kiana/Downloads/Hasil_Scraping_Pariwisata/travel-rec/data/processed/dataset_rekomendasi_final.csv")
df = DataPreprocessor().preprocess(df)
df = FeatureEngineer().create_combined_features(df)

model = SentenceTransformer("ibm-granite/granite-embedding-30m-english")
embeddings = model.encode(df["combined_features"].tolist(), convert_to_numpy=True)

# Gunakan best parameter dari fase eksperimen (misal alpha=0.2, threshold=0.55)
recommender = SemanticRecommender(df=df, embeddings=embeddings, similarity_matrix=None, model=model, alpha=0.2, min_threshold=0.55)
print("[INFO] Tuned Recommender ready for UX Sanity Check.")
# Out:
# [INFO] Preprocessing completed successfully. Dataset Shape: (1294, 23)
# [INFO] Tuning 1 Applied Successfully. Pseudo-sentence string formatted. Dataset Shape: (1294, 23)
# ...
# Loading weights: 100%|██████████████████| 103/103 [00:00<00:00, 689.00it/s]
# [INFO] Tuned Recommender ready for UX Sanity Check.

# %% [markdown]
# # Test Query & Verify Case-Sensitive Assets for UX Data Forwarding

# %%
# Simulasi user mencari tempat di Den Haag pada jam 7 malam
user_time = datetime.strptime("2026-05-25 19:00:00", "%Y-%m-%d %H:%M:%S")
query_text = "cozy restaurant with fresh food and nice cocktails"

recommendations = recommender.recommend_by_city_and_preference(
    city_name="Den Haag",
    preference_text=query_text,
    top_n=3,
    user_datetime=user_time
)

print(f"Total Buffer Candidates Returned: {len(recommendations)}")
recommendations
# Out:
# Total Buffer Candidates Returned: 9
#                               name      city      country  rating  \
# 1292             restaurant basaal  den haag  netherlands     4.6
# 1280             restaurant harper  den haag  netherlands     4.5
# 1293  by ami restaurant | den haag  den haag  netherlands     4.4
# 1275       el mamma bbq | den haag  den haag  netherlands     4.8
# 1285                 jamey bennett  den haag  netherlands     4.3
# 1277                       dekxels  den haag  netherlands     4.8
# 1278                   de basiliek  den haag  netherlands     4.6
# 1284         umami by han den haag  den haag  netherlands     4.5
# 1269                   butter bell  den haag  netherlands     4.6
#
#      indoor_outdoor   latitude  longitude         today_hours  cosine_score  \
# 1292         indoor  52.073767   4.316173     5:30 - 11:00 PM      0.744682
# 1280         indoor  52.079645   4.309759  9:00 AM - 11:00 PM      0.745581
# ...

# %% [markdown]
# # Test Query & Verify Case-Sensitive Assets for UX Data Forwarding

# %%
if not recommendations.empty:
    print("=== UX DATA FORWARDING VALIDATION ===")
    for idx, row in recommendations.head(2).iterrows():
        print(f"\nNama Tempat : {row['name']}")
        print(f"Tipe Zone   : {row['indoor_outdoor']}")
        print(f"Koordinat   : Lat={row['latitude']}, Long={row['longitude']}")
        print(f"Jam Hari Ini: {row['today_hours']}")
        print(f"Photo Link 1: {row['photo_link_1']} (Harus Case-Sensitive!)")
        print(f"Review Sample: \"{row['review_1'][:120]}...\"")
        print("-" * 50)
else:
    print("[ERROR] Rekomendasi kosong, periksa query atau timezone!")
# Out:
# === UX DATA FORWARDING VALIDATION ===
#
# Nama Tempat : restaurant basaal
# Tipe Zone   : indoor
# Koordinat   : Lat=52.0737671, Long=4.316173399999999
# Jam Hari Ini: 5:30 - 11:00 PM
# Photo Link 1: https://maps.googleapis.com/maps/api/place/photo?maxwidth=500&photo_reference=Ab43m-vPZYPM2ypYfezZw31s-pegy6va2QKSAsalNdru369rbBwzbvv93SonafEmhScjn6AUoa5Y401H6pGAILpO9etkGwHPUHCHjSLeBBo5NlAxFdK07Q7WsEBgmIbutzgdEzXdbuEBWWqoeI6Rv03LXd1XApoCRwz5uioEVkb7psFl0VHpgDyOjXTuLF_IZ341EgUDm8sE9a6W4e7Yw5zSVaXJvmRIlB86GFYVTnxvU_uf6KcEvdAauhjofg5AZYlNHKsVKhQGtaUT8HF3X9hy2RbA14ns99gy-5xJmBeKwKOeYw&key=AIzaSyCzghOGFC5qivuKfqjzP5Nm4cvDtlttBG0 (Harus Case-Sensitive!)
# Review Sample: "Finally -- a Bib Gourmand that actually deserves it in Den Haag!  Basaal -- wow. Just wow. This place is, in my humble o..."
# --------------------------------------------------
#
# Nama Tempat : restaurant harper
# Tipe Zone   : indoor
# Koordinat   : Lat=52.0796453, Long=4.309758899999999
# Jam Hari Ini: 9:00 AM - 11:00 PM
# ...
